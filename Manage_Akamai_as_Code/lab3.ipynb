# %% [markdown]
# # Lab 2. Terraform

# %% [markdown]
# ##### 1. find your **group_id** and **contract_id** using akamai cli.

# %%
akamai pm lg

# %%
export CID="ctr_V-41DUHPB"
export GID="grp_232865"

# %% [markdown]
# #### 2. list properties in your group.

# %%
akamai pm lpr -c $CID -g $GID

# %% [markdown]
# #### 3. export the property to **import.sh** file.

# %%
akamai terraform export-property "lab001.akamai-lab.com"

# %% [markdown]
# #### 4. create terraform configuration files.

# %%
chmod +x import.sh
./import.sh

# %% [markdown]
# #### 5. edit **Offload_origin.json** in *workspaces > lab2 > property-snippets* directory as shown in the screencast below.
# You will change *cs/jss* caching TTL from **30days** to **10days**.

# %% [markdown]
# screencast placeholder

# %% [markdown]
# #### 6. run **terraform plan** to review changes in advance.

# %%
terraform plan

# %% [markdown]
# #### 7. run **terraform apply** to make changes to your environment.

# %%
terraform apply --auto-approve
# Out:
# data.akamai_property_rules_template.rules: Reading...
# data.akamai_group.group: Reading...
# data.akamai_property_rules_template.rules: Read complete after 0s [id=da39a3ee5e6b4b0d3255bfef95601890afd80709]
# data.akamai_group.group: Read complete after 1s [id=grp_232865]
# data.akamai_contract.contract: Reading...
# data.akamai_contract.contract: Read complete after 0s [id=ctr_V-41DUHPB]
# akamai_edge_hostname.lab001-akamai-lab-com-edgesuite-net: Refreshing state... [id=ehn_5319732]
# akamai_property.lab001-akamai-lab-com: Refreshing state... [id=prp_906976]
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   + create
#   ~ update in-place
#
# Terraform will perform the following actions:
#
#   # akamai_edge_hostname.lab001-akamai-lab-com-edgesuite-net will be updated in-place
#   ~ resource "akamai_edge_hostname" "lab001-akamai-lab-com-edgesuite-net" {
# ...
